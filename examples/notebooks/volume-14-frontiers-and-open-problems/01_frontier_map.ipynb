# %% [markdown]
# # Volume 14. Frontier Map
#
# Question: which ambitious ideas are notes, which are experiments, and what would make them testable?
#
# This notebook keeps frontier directions organized without promoting them to claims.

# %%
from pathlib import Path

import pandas as pd

# %%
repo_root = Path.cwd()
while not (repo_root / "research" / "plans").exists():
    if repo_root.parent == repo_root:
        raise RuntimeError("Could not locate repository root")
    repo_root = repo_root.parent

paths = [
    "research/plans/BRIDGE_WEBSCALE_CURRICULUM.md",
    "research/plans/ASSEMBLIES_AS_NEURAL_COMPILER.md",
    "research/plans/ASSEMBLIES_MAPPED_CONNECTOMES.md",
    "research/plans/SELF_ASSEMBLING_NEURAL_NANOTECH.md",
    "research/plans/robotics_embodiment/ISAAC_LAB_ASSEMBLY_BRAINSTORM.md",
]
pd.DataFrame([{"path": path, "exists": (repo_root / path).exists()} for path in paths])

# %%
pd.DataFrame([
    {"frontier": "web-scale curriculum", "next evidence": "small corpus protocol with trace metrics", "claim status": "planning"},
    {"frontier": "neural compiler", "next evidence": "operation graph semantics and tests", "claim status": "framework idea"},
    {"frontier": "mapped connectomes", "next evidence": "partition and null-model comparison", "claim status": "hypothesis"},
    {"frontier": "embodied robotics", "next evidence": "encoder, readout, and task loop", "claim status": "future work"},
    {"frontier": "self-assembling substrates", "next evidence": "toy physical or simulated substrate test", "claim status": "speculative"},
])
